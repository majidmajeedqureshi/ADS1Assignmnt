# %% [markdown]
# # Library

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv("GDP_Growth_World_Development_Data.csv")

# %%
df
# Out:
#                                         Country Name Country Code  \
# 0                                     United Kingdom          GBR
# 1                                     United Kingdom          GBR
# 2                                          Australia          AUS
# 3                                          Australia          AUS
# 4                                       South Africa          ZAF
# 5                                       South Africa          ZAF
# 6                                        New Zealand          NZL
# 7                                        New Zealand          NZL
# 8                                                NaN          NaN
# 9                                                NaN          NaN
# 10                                               NaN          NaN
# 11  Data from database: World Development Indicators          NaN
# 12                          Last Updated: 09/16/2022          NaN
#
#                                           Series Name        Series Code  \
# 0                               GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 1   Adjusted savings: natural resources depletion ...  NY.ADJ.DRES.GN.ZS
# 2                               GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 3   Adjusted savings: natural resources depletion ...  NY.ADJ.DRES.GN.ZS
# 4                               GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 5   Adjusted savings: natural resources depletion ...  NY.ADJ.DRES.GN.ZS
# 6                               GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 7   Adjusted savings: natural resources depletion ...  NY.ADJ.DRES.GN.ZS
# 8                                                 NaN                NaN
# 9                                                 NaN                NaN
# 10                                                NaN                NaN
# 11                                                NaN                NaN
# 12                                                NaN                NaN
#
#     1980 [YR1980]  1981 [YR1981]  1982 [YR1982]  1983 [YR1983]  1984 [YR1984]  \
# 0        2.031368       0.787744       1.994891       4.221856       2.269105
# 1        1.503493       1.628206       1.248925       1.720998       1.928547
# 2        3.035399       3.338807       3.322868       2.221969       4.595924
# 3        3.393419       2.395250       1.849031       2.228652       2.284208
# 4        6.620583       5.360791       0.383419       1.846558       5.099152
# 5        8.021072       6.454871       6.172976       5.259718       2.719672
# 6        1.283930       4.655922       0.929690       3.491758       4.793319
# 7        0.232161       0.216183       0.257603       0.315574       0.447976
# 8             NaN            NaN            NaN            NaN            NaN
# 9             NaN            NaN            NaN            NaN            NaN
# 10            NaN            NaN            NaN            NaN            NaN
# 11            NaN            NaN            NaN            NaN            NaN
# 12            NaN            NaN            NaN            NaN            NaN
#
#     1985 [YR1985]  ...  2006 [YR2006]  2007 [YR2007]  2008 [YR2008]  \
# 0        4.147415  ...       2.584105       2.269487       0.239638
# 1        1.993058  ...       0.851540       0.805194       1.181996
# 2        5.252115  ...       2.726893       3.768488       3.577015
# 3        2.810482  ...       2.595953       3.124515       3.466169
# 4        1.211541  ...       5.603806       5.360474       3.191044
# 5        5.832153  ...       2.171487       2.840373       5.702835
# 6        1.615423  ...       2.881062       3.028160       1.111523
# 7        0.519375  ...       0.533626       0.763120       1.479667
# 8             NaN  ...            NaN            NaN            NaN
# 9             NaN  ...            NaN            NaN            NaN
# 10            NaN  ...            NaN            NaN            NaN
# 11            NaN  ...            NaN            NaN            NaN
# 12            NaN  ...            NaN            NaN            NaN
#
#     2009 [YR2009]  2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  \
# 0        4.247356       2.131438       1.457563       1.469888       1.890018
# 1        0.790135       0.877960       1.009589       0.825371       0.650651
# 2        1.866832       2.172337       2.469746       3.917362       2.600212
# 3        2.046520       2.720819       3.030269       2.243634       1.930673
# 4        1.538089       3.039733       3.168556       2.396232       2.485468
# 5        2.101959       3.321567       3.699839       2.851694       2.776319
# 6        0.135170       1.523878       2.251759       2.245303       2.695417
# 7        0.956984       1.047099       1.079979       0.910000       0.734505
# 8             NaN            NaN            NaN            NaN            NaN
# 9             NaN            NaN            NaN            NaN            NaN
# 10            NaN            NaN            NaN            NaN            NaN
# 11            NaN            NaN            NaN            NaN            NaN
# 12            NaN            NaN            NaN            NaN            NaN
#
#     2014 [YR2014]  2015 [YR2015]
# 0        2.991165       2.622597
# 1        0.505812       0.289809
# 2        2.562932       2.172205
# 3        1.937598       1.467298
# 4        1.413826       1.321862
# 5        1.974529       1.039391
# 6        3.815428       3.744332
# 7        0.726529       0.573418
# 8             NaN            NaN
# 9             NaN            NaN
# 10            NaN            NaN
# 11            NaN            NaN
# 12            NaN            NaN
#
# [13 rows x 40 columns]

# %% [markdown]
# # Remove None Value

# %%
df = df.dropna(axis=0)

# %%
df
# Out:
#      Country Name Country Code  \
# 0  United Kingdom          GBR
# 1  United Kingdom          GBR
# 2       Australia          AUS
# 3       Australia          AUS
# 4    South Africa          ZAF
# 5    South Africa          ZAF
# 6     New Zealand          NZL
# 7     New Zealand          NZL
#
#                                          Series Name        Series Code  \
# 0                              GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 1  Adjusted savings: natural resources depletion ...  NY.ADJ.DRES.GN.ZS
# 2                              GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 3  Adjusted savings: natural resources depletion ...  NY.ADJ.DRES.GN.ZS
# 4                              GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 5  Adjusted savings: natural resources depletion ...  NY.ADJ.DRES.GN.ZS
# 6                              GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 7  Adjusted savings: natural resources depletion ...  NY.ADJ.DRES.GN.ZS
#
#    1980 [YR1980]  1981 [YR1981]  1982 [YR1982]  1983 [YR1983]  1984 [YR1984]  \
# 0       2.031368       0.787744       1.994891       4.221856       2.269105
# 1       1.503493       1.628206       1.248925       1.720998       1.928547
# 2       3.035399       3.338807       3.322868       2.221969       4.595924
# 3       3.393419       2.395250       1.849031       2.228652       2.284208
# 4       6.620583       5.360791       0.383419       1.846558       5.099152
# 5       8.021072       6.454871       6.172976       5.259718       2.719672
# 6       1.283930       4.655922       0.929690       3.491758       4.793319
# 7       0.232161       0.216183       0.257603       0.315574       0.447976
#
#    1985 [YR1985]  ...  2006 [YR2006]  2007 [YR2007]  2008 [YR2008]  \
# 0       4.147415  ...       2.584105       2.269487       0.239638
# 1       1.993058  ...       0.851540       0.805194       1.181996
# 2       5.252115  ...       2.726893       3.768488       3.577015
# 3       2.810482  ...       2.595953       3.124515       3.466169
# 4       1.211541  ...       5.603806       5.360474       3.191044
# 5       5.832153  ...       2.171487       2.840373       5.702835
# 6       1.615423  ...       2.881062       3.028160       1.111523
# 7       0.519375  ...       0.533626       0.763120       1.479667
#
#    2009 [YR2009]  2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  \
# 0       4.247356       2.131438       1.457563       1.469888       1.890018
# 1       0.790135       0.877960       1.009589       0.825371       0.650651
# 2       1.866832       2.172337       2.469746       3.917362       2.600212
# 3       2.046520       2.720819       3.030269       2.243634       1.930673
# 4       1.538089       3.039733       3.168556       2.396232       2.485468
# 5       2.101959       3.321567       3.699839       2.851694       2.776319
# 6       0.135170       1.523878       2.251759       2.245303       2.695417
# 7       0.956984       1.047099       1.079979       0.910000       0.734505
#
#    2014 [YR2014]  2015 [YR2015]
# 0       2.991165       2.622597
# 1       0.505812       0.289809
# 2       2.562932       2.172205
# 3       1.937598       1.467298
# 4       1.413826       1.321862
# 5       1.974529       1.039391
# 6       3.815428       3.744332
# 7       0.726529       0.573418
#
# [8 rows x 40 columns]

# %% [markdown]
# # Rename Column of Dataset

# %%
df.rename(columns={'Country Name': 'country'}, inplace=True)
# Out:
# C:\Users\sunny\AppData\Local\Temp\ipykernel_11800\1625075815.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Country Name': 'country'}, inplace=True)

# %%
df
# Out:
#           country Country Code  \
# 0  United Kingdom          GBR
# 1  United Kingdom          GBR
# 2       Australia          AUS
# 3       Australia          AUS
# 4    South Africa          ZAF
# 5    South Africa          ZAF
# 6     New Zealand          NZL
# 7     New Zealand          NZL
#
#                                          Series Name        Series Code  \
# 0                              GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 1  Adjusted savings: natural resources depletion ...  NY.ADJ.DRES.GN.ZS
# 2                              GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 3  Adjusted savings: natural resources depletion ...  NY.ADJ.DRES.GN.ZS
# 4                              GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 5  Adjusted savings: natural resources depletion ...  NY.ADJ.DRES.GN.ZS
# 6                              GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 7  Adjusted savings: natural resources depletion ...  NY.ADJ.DRES.GN.ZS
#
#    1980 [YR1980]  1981 [YR1981]  1982 [YR1982]  1983 [YR1983]  1984 [YR1984]  \
# 0       2.031368       0.787744       1.994891       4.221856       2.269105
# 1       1.503493       1.628206       1.248925       1.720998       1.928547
# 2       3.035399       3.338807       3.322868       2.221969       4.595924
# 3       3.393419       2.395250       1.849031       2.228652       2.284208
# 4       6.620583       5.360791       0.383419       1.846558       5.099152
# 5       8.021072       6.454871       6.172976       5.259718       2.719672
# 6       1.283930       4.655922       0.929690       3.491758       4.793319
# 7       0.232161       0.216183       0.257603       0.315574       0.447976
#
#    1985 [YR1985]  ...  2006 [YR2006]  2007 [YR2007]  2008 [YR2008]  \
# 0       4.147415  ...       2.584105       2.269487       0.239638
# 1       1.993058  ...       0.851540       0.805194       1.181996
# 2       5.252115  ...       2.726893       3.768488       3.577015
# 3       2.810482  ...       2.595953       3.124515       3.466169
# 4       1.211541  ...       5.603806       5.360474       3.191044
# 5       5.832153  ...       2.171487       2.840373       5.702835
# 6       1.615423  ...       2.881062       3.028160       1.111523
# 7       0.519375  ...       0.533626       0.763120       1.479667
#
#    2009 [YR2009]  2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  \
# 0       4.247356       2.131438       1.457563       1.469888       1.890018
# 1       0.790135       0.877960       1.009589       0.825371       0.650651
# 2       1.866832       2.172337       2.469746       3.917362       2.600212
# 3       2.046520       2.720819       3.030269       2.243634       1.930673
# 4       1.538089       3.039733       3.168556       2.396232       2.485468
# 5       2.101959       3.321567       3.699839       2.851694       2.776319
# 6       0.135170       1.523878       2.251759       2.245303       2.695417
# 7       0.956984       1.047099       1.079979       0.910000       0.734505
#
#    2014 [YR2014]  2015 [YR2015]
# 0       2.991165       2.622597
# 1       0.505812       0.289809
# 2       2.562932       2.172205
# 3       1.937598       1.467298
# 4       1.413826       1.321862
# 5       1.974529       1.039391
# 6       3.815428       3.744332
# 7       0.726529       0.573418
#
# [8 rows x 40 columns]

# %% [markdown]
# # Divide dataset for Population growth & Energy Consumption

# %%
gdp  = df.loc[df['Series Code'] == "NY.GDP.MKTP.KD.ZG"]
adj  = df.loc[df['Series Code'] == "NY.ADJ.DRES.GN.ZS"]

# %% [markdown]
# # Remove unnecessary column

# %%
gdp.drop(['Country Code','Series Name', 'Series Code'], axis=1, inplace=True)
adj.drop(['Country Code','Series Name', 'Series Code'], axis=1, inplace=True)
# Out:
# C:\Users\sunny\AppData\Local\Temp\ipykernel_11800\2257046854.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp.drop(['Country Code','Series Name', 'Series Code'], axis=1, inplace=True)
# C:\Users\sunny\AppData\Local\Temp\ipykernel_11800\2257046854.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adj.drop(['Country Code','Series Name', 'Series Code'], axis=1, inplace=True)

# %%
gdp.set_index('country', inplace=True)
adj.set_index('country', inplace=True)

# %% [markdown]
# # Graph Plot Functions
#     - These function get different parameters
#     - Dataframe
#     - Countries Name
#     - Years
#     - Title of graph
#     - filename that saved in local file

# %%
def graph_plot(df, countries, years, title, filename):
    # figure size is the graph image size
    # This is a simple graph.
    df.loc[countries, years].T.plot(figsize=(14, 8)) 
    title = plt.title(title) 
    plt.savefig(filename)
    plt.show()

# %%
def graph_plot2(df, countries, years, title,  filename):
    # figure size is the graph image size
    # This graph type is Area.
    df.loc[countries, years].T.plot(kind='area', figsize=(14, 8))
    title = plt.title(title)
    plt.savefig(filename)
    plt.show()

# %%
def graph_bar(df, country, years, title, filename):
    # figure size is the graph image size
    # This is Bar graph
    df.loc[country, years].plot(kind='bar',figsize=(14, 8))
    title = plt.title(title)
    plt.savefig(filename)
    plt.show()

# %%
def graph_barh(df, countries, years, title, filename):
    # figure size is the graph image size
    # This is Barh graph
    df.loc[countries, years].transpose().plot(kind='barh', figsize=(20, 14), stacked=False)
    title = plt.title(title)
    plt.savefig(filename)
    plt.show()

# %%
def heatmap(data, row_labels, col_labels, ax=None,
            cbar_kw=None, cbarlabel="", **kwargs):
# Create a heatmap from a numpy array and two lists of labels.
#     - data - A 2D numpy array of shape (M, N).
#     - row_labels - A list or array of length M with the labels for the rows.
#     - col_labels - A list or array of length N with the labels for the columns.

    if ax is None:
        ax = plt.gca()

    if cbar_kw is None:
        cbar_kw = {}

    # Plot the heatmap
    im = ax.imshow(data, **kwargs)

    # Create colorbar
    cbar = ax.figure.colorbar(im, ax=ax, **cbar_kw)
    cbar.ax.set_ylabel(cbarlabel, rotation=-90, va="bottom")

    # Show all ticks and label them with the respective list entries.
    ax.set_xticks(np.arange(data.shape[1]), labels=col_labels)
    ax.set_yticks(np.arange(data.shape[0]), labels=row_labels)

    # Let the horizontal axes labeling appear on top.
    ax.tick_params(top=True, bottom=False,
                   labeltop=True, labelbottom=False)

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=-30, ha="right",
             rotation_mode="anchor")

    # Turn spines off and create white grid.
    ax.spines[:].set_visible(False)

    ax.set_xticks(np.arange(data.shape[1]+1)-.5, minor=True)
    ax.set_yticks(np.arange(data.shape[0]+1)-.5, minor=True)
    ax.grid(which="minor", color="w", linestyle='-', linewidth=3)
    ax.tick_params(which="minor", bottom=False, left=False)

    return im, cbar

# %%
def graph_heatmap(df, countries, years, title, filename):
    fig, ax = plt.subplots(figsize=(7, 7))
    
    im, cbar = heatmap(df[years].T, df[years], countries, ax=ax,
                       cmap="viridis", cbarlabel=title)
    plt.savefig(filename)
    fig.tight_layout()
    plt.show()

# %% [markdown]
# # Years & Country Information
#     - Year used 1980-2020
#     - Countries used 'United Kingdom', 'Australia', 'South Africa', 'New Zealand'

# %%
# years = list(population_growth.columns)
years = ['1980 [YR1980]', '1985 [YR1985]', '1990 [YR1990]', '1995 [YR1995]', '2000 [YR2000]', 
         '2005 [YR2005]', '2010 [YR2010]', '2015 [YR2015]']

countries = ['United Kingdom', 'Australia', 'South Africa', 'New Zealand']

# %% [markdown]
# # GDP Growth Line Graph

# %%
graph_plot(gdp, countries, years, "GDP growth (annual %)", "gdp_1.jpg")

# %% [markdown]
# # GDP Growth Bar Graph

# %%
graph_bar(gdp, countries, years, 'GDP growth (annual %)', "gdp_2.jpg")

# %% [markdown]
# # GDP Growth HeatMap

# %%
graph_heatmap(gdp, countries, years, "GDP growth (annual %)", "gdp_3.jpg")

# %% [markdown]
# # Natural Resources Depletion Line Graph

# %%
graph_plot(adj, countries, years, 'Natural Resources Depletion (% of GNI)', "adj_1.jpg")

# %% [markdown]
# # Energy Consumption Bar Graph

# %%
graph_bar(adj, countries, years, 'Natural Resources Depletion (% of GNI)', "adj_2.jpg")

# %% [markdown]
# # Energy Consumption Heat Graph

# %%
graph_heatmap(adj, countries, years, "Natural Resources Depletion (% of GNI)", "adj_3.jpg")

# %%
gdp[years].T
# Out:
# country        United Kingdom  Australia  South Africa  New Zealand
# 1980 [YR1980]        2.031368   3.035399      6.620583     1.283930
# 1985 [YR1985]        4.147415   5.252115      1.211541     1.615423
# 1990 [YR1990]        0.733756   3.573507      0.317760     0.152973
# 1995 [YR1995]        2.531670   3.833831      3.100000     4.722465
# 2000 [YR2000]        3.672369   3.912428      4.200000     2.905141
# 2005 [YR2005]        2.593280   3.160338      5.277052     3.320717
# 2010 [YR2010]        2.131438   2.172337      3.039733     1.523878
# 2015 [YR2015]        2.622597   2.172205      1.321862     3.744332

# %%
adj[years].T
# Out:
# country        United Kingdom  Australia  South Africa  New Zealand
# 1980 [YR1980]        1.503493   3.393419      8.021072     0.232161
# 1985 [YR1985]        1.993058   2.810482      5.832153     0.519375
# 1990 [YR1990]        0.865604   2.034459      2.634423     0.697761
# 1995 [YR1995]        0.519549   1.354007      1.514406     0.337940
# 2000 [YR2000]        0.890650   1.858572      1.217264     0.852663
# 2005 [YR2005]        0.745885   2.049529      1.936865     0.427238
# 2010 [YR2010]        0.877960   2.720819      3.321567     1.047099
# 2015 [YR2015]        0.289809   1.467298      1.039391     0.573418
